# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelinolionel/DMC_Curso_Python1/blob/main/Sesi%C3%B3n05_FDP_OG7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operadores Aritméticos
# En programación y matemáticas, los operadores aritméticos son aquellos que manipulan los datos de tipo numérico, es decir, permiten la realización de operaciones matemáticas (sumas, restas, multiplicaciones, etc.).
#
# El resultado de una operación aritmética es un dato aritmético, es decir, si ambos valores son números enteros el resultado será de tipo entero; si alguno de ellos o ambos son números con decimales, el resultado también lo será. A continuación, añadimos los principales conjuntos numéricos que utilizaremos en las siguientes lecciones:
#
#
# * Enteros: Z = {..., -2, -1, 0, 1, 2, ...}
# * Naturales: N = {1, 2, 3, ...} *Algunos autores consideran también el 0.
# * Racionales: Q = {..., -3/4, -1/2, 1/2, 3/4, ...}
# * Irracionales: I ={..., √2, PI, ...}
# * Reales: R = { Z, Q, I }
#
# A modo de ejemplo, puedes observar en la siguiente tabla el resultado de utilizar operadores aritméticos:
#
# ![Captura.JPG](data:image/jpeg;base64,...)

# %%
#SUMA
suma = 3 + 5.6
print(suma)
type(suma)
# Out:
# 8.6
# float

# %%
#RESTA
resta = 4 - 1
print(resta)
# Out:
# 3

# %%
#MULTIPLICACIÓN
multiplicación = 3 * 6 
print(multiplicación)
# Out:
# 18

# %%
#POTENCIA
potencia = 4 ** 2
print(potencia)
# Out:
# 64

# %%
#DIVISION COCIENTE
división_cociente = 15 / 2 
print(división_cociente)
# Out:
# 7.5

# %%
#DIVISION PARTE ENTERA
división = 15 // 2 
print(división)
# Out:
# 7

# %%
#RESTO
resto = 7 % 2
print(resto)
# Out:
# 1

# %%
def sumar():
    print(5 + 10)

sumar()
# Out:
# 15

# %%
def sumar(number1, number2):
    print(number1 + number2)
    

sumar(10, 15)
# Out:
# 25

# %%
def sumar(number1, number2=20):
     print(number1 + number2)
     
sumar(10, 15) # 25
sumar(10)
# Out:
# 25
# 30

# %%
def sumar(numbers):
    result = 0
    for number in numbers:
        result += number
    print(result)

sumar([4,5,1])
# Out:
# 10

# %% [markdown]
# ## Actividad de la Sesión
#
# 1.   Crear una función calculadora que reciba 3 parametros (Valor1, Valor2, Operación)
# 2. Almacenar el resultado en una variable y mostrar el resultado por pantalla

# %%
def calculadora(valor1,valor2,operacion):
  if operacion=="+":
    suma=valor1+valor2
    print(f"{suma}")
  elif operacion=="-":
    resta=valor1-valor2
    print(f"{resta}")
  elif operacion=="*":
    multiplicacion=valor1*valor2
    print(f"{multiplicacion}")
  else:
    if operacion=="/" and valor2!=0:
      division=valor1/valor2
      print(f"{division}")
    else:
      print("El 2do. número debe ser diferente de cero")

calculadora(7,14,"/")
# Out:
# La división es : 0.5
